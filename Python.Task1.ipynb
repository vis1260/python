# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/VISHNU/PythonDatasets/MyCSVs/Students1CSVFile.csv")

# %%
print(df.head())
# Out:
#    RegNum      Name  Maths  Science
# 0     101    Jayant     90       65
# 1     102    Varsha     95       85
# 2     103   Srujana     80       76
# 3     104  Susmitha     86       68
# 4     105  Shashank     75       74

# %%
import seaborn as sns
plt.figure(figsize = (8,5))

plt.title("Maths Score of the students")
#data = np.random.randint(df[["Maths"],["Science"]])
plt.xlabel("Maths")
plt.ylabel("Science")
data = np.random.randint(1, 100, (10, 10))
#z =  sns.heatmap()

sns.heatmap(data)
plt.show()
